# %%
import mod_funcs as mf
import gzip
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider
import ipywidgets as widgets
# %matplotlib inline

mf.initialize()
# Out:
# interactive(children=(Dropdown(description='Spectra_type', options=(('Same params for all absorption bins', 1)…

# %%
mf.make_sliders()
# Out:
# interactive(children=(IntSlider(value=20, description='Threads', min=2), IntSlider(value=8000, description='St…
# interactive(children=(FloatSlider(value=1.7999999999999998, description='Γ', max=2.2, min=1.4, step=0.01), Flo…

# %%
mf.execute()
# Out:
# Unabsorbed: <R>: 1.0, σ_R: 0.5, <Γ>: 1.7999999999999998, σ_Γ: 0.25, <E>: 270.0, σ_E:50.0
#
# Probability with respect to errors in each data set (shown in figure with error bars):
# Chandra: 0.0
# ASCA: 0.0
# RXTE: 0.0
# Swift-BAT: 0.0
# INTEGRAL: 0.0
# HEAO (1999): 0.0
# HEAO-A4 (1997): 0.0
#
# Comments:
# Disagrees with all data sets at low energies
# Disagrees with all data sets at high energies.
# Result: Rejected
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="432">
# Convergence of the best fit model prediction:
